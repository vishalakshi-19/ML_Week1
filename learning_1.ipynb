# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalakshi-19/ML_Week1/blob/main/learning_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("khushikyad001/ai-impact-on-jobs-2030")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 85.4k/85.4k [00:00<00:00, 22.3MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/khushikyad001/ai-impact-on-jobs-2030/versions/1

# %%
csv_files = [f for f in os.listdir(path) if f.endswith('.csv')]
df = pd.read_csv(os.path.join(path, csv_files[0]))

# %%
df.head()
# Out:
#              Job_Title  Average_Salary  Years_Experience Education_Level  \
# 0       Security Guard           45795                28        Master's
# 1   Research Scientist          133355                20             PhD
# 2  Construction Worker          146216                 2     High School
# 3    Software Engineer          136530                13             PhD
# 4    Financial Analyst           70397                22     High School
#
#    AI_Exposure_Index  Tech_Growth_Factor  Automation_Probability_2030  \
# 0               0.18                1.28                         0.85
# 1               0.62                1.11                         0.05
# 2               0.86                1.18                         0.81
# 3               0.39                0.68                         0.60
# 4               0.52                1.46                         0.64
#
#   Risk_Category  Skill_1  Skill_2  Skill_3  Skill_4  Skill_5  Skill_6  \
# ...

# %%
df.describe()
# Out:
#        Average_Salary  Years_Experience  AI_Exposure_Index  \
# count     3000.000000       3000.000000        3000.000000
# mean     89372.279000         14.677667           0.501283
# std      34608.088767          8.739788           0.284004
# min      30030.000000          0.000000           0.000000
# 25%      58640.000000          7.000000           0.260000
# 50%      89318.000000         15.000000           0.500000
# 75%     119086.500000         22.000000           0.740000
# max     149798.000000         29.000000           1.000000
#
#        Tech_Growth_Factor  Automation_Probability_2030      Skill_1  \
# count         3000.000000                  3000.000000  3000.000000
# mean             0.995343                     0.501503     0.496973
# std              0.287669                     0.247881     0.287888
# min              0.500000                     0.050000     0.000000
# 25%              0.740000                     0.310000     0.240000
# ...

# %%
df.sample(5)
# Out:
#               Job_Title  Average_Salary  Years_Experience Education_Level  \
# 473   Financial Analyst           77013                29        Master's
# 2168  Marketing Manager          134560                 4             PhD
# 1997      UX Researcher           45231                 0     High School
# 2742     Data Scientist           65714                11     High School
# 1734  Marketing Manager           81356                 7     High School
#
#       AI_Exposure_Index  Tech_Growth_Factor  Automation_Probability_2030  \
# 473                0.13                0.80                         0.53
# 2168               0.58                1.18                         0.55
# 1997               0.01                1.07                         0.55
# 2742               0.74                0.69                         0.63
# 1734               0.14                0.94                         0.36
#
#      Risk_Category  Skill_1  Skill_2  Skill_3  Skill_4  Skill_5  Skill_6  \
# ...

# %%
df.shape
# Out:
# (3000, 18)

# %%
df.isna().sum()
# Out:
# Job_Title                      0
# Average_Salary                 0
# Years_Experience               0
# Education_Level                0
# AI_Exposure_Index              0
# Tech_Growth_Factor             0
# Automation_Probability_2030    0
# Risk_Category                  0
# Skill_1                        0
# Skill_2                        0
# Skill_3                        0
# Skill_4                        0
# Skill_5                        0
# Skill_6                        0
# Skill_7                        0
# Skill_8                        0
# Skill_9                        0
# Skill_10                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
sns.boxplot(df['Average_Salary'])
# Out:
# <Axes: ylabel='Average_Salary'>

# %%
df['Years_Experience'].skew()
# Out:
# np.float64(-0.008568207240754888)

# %%
plt.hist(df['Years_Experience'])
# Out:
# (array([287., 308., 287., 319., 279., 288., 290., 318., 288., 336.]),
#  array([ 0. ,  2.9,  5.8,  8.7, 11.6, 14.5, 17.4, 20.3, 23.2, 26.1, 29. ]),
#  <BarContainer object of 10 artists>)

# %%
df['AI_Exposure_Index'].value_counts().plot(kind='pie',autopct='%2f')
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(df['AI_Exposure_Index'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.barplot(x=df['AI_Exposure_Index'],y=df['Years_Experience'])
# Out:
# <Axes: xlabel='AI_Exposure_Index', ylabel='Years_Experience'>

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop('Automation_Probability_2030',axis=1),df['Automation_Probability_2030'],test_size=0.2,random_state=42)

# %%
y_train
# Out:
# 642     0.86
# 700     0.92
# 226     0.42
# 1697    0.80
# 1010    0.41
#         ...
# 1638    0.52
# 1095    0.37
# 1130    0.36
# 1294    0.84
# 860     0.16
# Name: Automation_Probability_2030, Length: 2400, dtype: float64

# %%
y_test
# Out:
# 1801    0.54
# 1190    0.75
# 1817    0.45
# 251     0.42
# 2505    0.34
#         ...
# 104     0.70
# 2087    0.27
# 599     0.38
# 1756    0.60
# 1323    0.82
# Name: Automation_Probability_2030, Length: 600, dtype: float64

# %%
x_train.shape,x_test.shape
# Out:
# ((2400, 17), (600, 17))

# %% [markdown]
# before standard scaling you gotta convert the categorical columns to numerical ones.

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
df['Education_Level'].unique()
# Out:
# array(["Master's", 'PhD', 'High School', "Bachelor's"], dtype=object)

# %%
oe=OrdinalEncoder(categories=[["High School","Bachelor's","Master's","PhD"]])

# %%
oe
# Out:
# OrdinalEncoder(categories=[['High School', "Bachelor's", "Master's", 'PhD']])

# %%
x_train['Education_Level']=oe.fit_transform(x_train[['Education_Level']])

# %%
x_train
# Out:
#                Job_Title  Average_Salary  Years_Experience  Education_Level  \
# 642     Customer Support          105569                15              3.0
# 700        Retail Worker          135301                25              2.0
# 226       Data Scientist           93059                18              0.0
# 1697    Customer Support          141459                26              3.0
# 1010                Chef           40040                29              0.0
# ...                  ...             ...               ...              ...
# 1638   Software Engineer          127364                 0              2.0
# 1095       UX Researcher           37163                 0              1.0
# 1130   Financial Analyst          118670                29              2.0
# 1294        Truck Driver           44436                10              1.0
# 860   Research Scientist          116545                27              1.0
#
# ...

# %%
oe=OrdinalEncoder(categories=[['Low','Medium','High']])

# %%
x_train['Risk_Category']=oe.fit_transform(x_train[['Risk_Category']])

# %%
x_train
# Out:
#                Job_Title  Average_Salary  Years_Experience  Education_Level  \
# 642     Customer Support          105569                15              3.0
# 700        Retail Worker          135301                25              2.0
# 226       Data Scientist           93059                18              0.0
# 1697    Customer Support          141459                26              3.0
# 1010                Chef           40040                29              0.0
# ...                  ...             ...               ...              ...
# 1638   Software Engineer          127364                 0              2.0
# 1095       UX Researcher           37163                 0              1.0
# 1130   Financial Analyst          118670                29              2.0
# 1294        Truck Driver           44436                10              1.0
# 860   Research Scientist          116545                27              1.0
#
# ...

# %%
df['Job_Title'].value_counts()
# Out:
# Job_Title
# Software Engineer      175
# UX Researcher          167
# Data Scientist         167
# Teacher                166
# Graphic Designer       160
# HR Specialist          157
# Construction Worker    156
# Retail Worker          155
# Security Guard         154
# Truck Driver           153
# Financial Analyst      151
# Research Scientist     149
# Nurse                  142
# Chef                   141
# AI Engineer            140
# Mechanic               136
# Marketing Manager      134
# Customer Support       133
# Lawyer                 132
# Doctor                 132
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(sparse_output=False,drop='first')

# %%
x_train['Job_Title']=ohe.fit_transform(x_train[['Job_Title']])

# %%
x_train
# Out:
#       Job_Title  Average_Salary  Years_Experience  Education_Level  \
# 642         0.0          105569                15              3.0
# 700         0.0          135301                25              2.0
# 226         0.0           93059                18              0.0
# 1697        0.0          141459                26              3.0
# 1010        1.0           40040                29              0.0
# ...         ...             ...               ...              ...
# 1638        0.0          127364                 0              2.0
# 1095        0.0           37163                 0              1.0
# 1130        0.0          118670                29              2.0
# 1294        0.0           44436                10              1.0
# 860         0.0          116545                27              1.0
#
#       AI_Exposure_Index  Tech_Growth_Factor  Risk_Category  Skill_1  Skill_2  \
# 642                0.58                1.20            2.0     0.98     0.14
# ...

# %%
sns.distplot(df['Average_Salary'])
# Out:
# /tmp/ipykernel_1689/4139531789.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Average_Salary'])
# <Axes: xlabel='Average_Salary', ylabel='Density'>

# %%
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()

# %%
# First, ensure that x_train's 'Job_Title' column is properly one-hot encoded.
# It appears the previous one-hot encoding in cell 'gKWXaPltw0Rb' did not correctly expand the column.

# Re-apply one-hot encoding for 'Job_Title'
# ohe is already defined from cell -bYjOWGPutlZ
job_title_encoded_data = ohe.fit_transform(x_train[['Job_Title']])

# Create a DataFrame from the encoded data with appropriate column names
# Ensure the index matches x_train for correct concatenation
encoded_job_titles_df = pd.DataFrame(job_title_encoded_data, columns=ohe.get_feature_names_out(['Job_Title']), index=x_train.index)

# Drop the original 'Job_Title' column from x_train
x_train = x_train.drop('Job_Title', axis=1)

# Concatenate the new one-hot encoded columns to x_train
x_train = pd.concat([x_train, encoded_job_titles_df], axis=1)

# Now, apply the scaler
x_train_scaled = scaler.fit_transform(x_train)

# %%
x_train
# Out:
#       Average_Salary  Years_Experience  Education_Level  AI_Exposure_Index  \
# 642           105569                15              3.0               0.58
# 700           135301                25              2.0               0.06
# 226            93059                18              0.0               0.11
# 1697          141459                26              3.0               0.02
# 1010           40040                29              0.0               0.05
# ...              ...               ...              ...                ...
# 1638          127364                 0              2.0               0.70
# 1095           37163                 0              1.0               0.44
# 1130          118670                29              2.0               0.53
# 1294           44436                10              1.0               0.04
# 860           116545                27              1.0               0.03
#
# ...

# %%
df.Job_Title
# Out:
# 0            Security Guard
# 1        Research Scientist
# 2       Construction Worker
# 3         Software Engineer
# 4         Financial Analyst
#                ...
# 2995                 Doctor
# 2996          UX Researcher
# 2997         Data Scientist
# 2998       Graphic Designer
# 2999       Graphic Designer
# Name: Job_Title, Length: 3000, dtype: object

# %%
pd.concat([x_train,df.Job_Title],axis=1)
# Out:
#       Average_Salary  Years_Experience  Education_Level  AI_Exposure_Index  \
# 642         105569.0              15.0              3.0               0.58
# 700         135301.0              25.0              2.0               0.06
# 226          93059.0              18.0              0.0               0.11
# 1697        141459.0              26.0              3.0               0.02
# 1010         40040.0              29.0              0.0               0.05
# ...              ...               ...              ...                ...
# 2988             NaN               NaN              NaN                NaN
# 2991             NaN               NaN              NaN                NaN
# 2994             NaN               NaN              NaN                NaN
# 2996             NaN               NaN              NaN                NaN
# 2999             NaN               NaN              NaN                NaN
#
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=[]
for i in range (x_train.shape[1]):
  vif.append(variance_inflation_factor(x_train.values,i))
pd.DataFrame({'vif':vif},index=x_train.columns)
# Out:
#                           vif
# Average_Salary       6.794815
# Years_Experience     3.645781
# Education_Level      2.665272
# AI_Exposure_Index    3.925119
# Tech_Growth_Factor  10.317919
# Risk_Category        2.951568
# Skill_1              3.814679
# Skill_2              3.756998
# Skill_3              3.865777
# Skill_4              3.803145
# Skill_5              3.776146
# Skill_6              3.929551
# Skill_7              3.859580
# Skill_8              3.927049
# Skill_9              3.909240
# Skill_10             3.762013
# Job_Title_1.0        1.064178

# %%
df.Automation_Probability_2030
# Out:
# 0       0.85
# 1       0.05
# 2       0.81
# 3       0.60
# 4       0.64
#         ...
# 2995    0.20
# 2996    0.35
# 2997    0.39
# 2998    0.46
# 2999    0.49
# Name: Automation_Probability_2030, Length: 3000, dtype: float64
